# %%
import pymysql
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = pymysql.connect(
    host = '192.168.44.54', 
    port = 3306, 
    user = 'liuzhilun', 
    password = 'Gax@q123+', 
    db = 'gac_lzl', 
    charset = 'utf8'
)

# %%
sql = "select Sn,Sn_Label_1L, Sn_Label_2L,Sn_Count from CF_Sn_SlowChgLoad_2L"

# %%
df = pd.read_sql(sql,conn)

# %%
df
# Out:
#        Sn  Sn_Label_1L  Sn_Label_2L  Sn_Count
# 0       2           22          220         1
# 1       2           22          220         1
# 2       2           22          220         1
# 3       2           22          220         1
# 4       2           22          220         1
# ...    ..          ...          ...       ...
# 68537   2           22          220         1
# 68538   2           21          210         1
# 68539   2           21          210         1
# 68540   2           21          210         1
# 68541   2           21          210         1
#
# [68542 rows x 4 columns]

# %%
sns.set(style="darkgr") #这是seaborn默认的风格
plt.figure(figsize=(10,8))
sns.barplot(x = 'Sn_Label_1L', kind = 'Sn_Count',data =df )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c582b298bf73> in <module>
# ----> 1 sns.set(style="darkgr") #这是seaborn默认的风格
#       2 plt.figure(figsize=(10,8))
#       3 sns.barplot(x = 'Sn_Label_1L', kind = 'Sn_Count',data =df )
#
# D:\Setups\apps\Aanconda\lib\site-packages\seaborn\rcmod.py in set(*args, **kwargs)
#     120 def set(*args, **kwargs):
#     121     """Alias for :func:`set_theme`, which is the preferred interface."""
# --> 122     set_theme(*args, **kwargs)
#     123
#     124
#
# D:\Setups\apps\Aanconda\lib\site-packages\seaborn\rcmod.py in set_theme(context, style, palette, font, font_scale, color_codes, rc)
#     112     """
#     113     set_context(context, font_scale)
# --> 114     set_style(style, rc={"font.family": font})
#     115     set_palette(palette, color_codes=color_codes)
#     116     if rc is not None:
#
# ...

# %%
sns.set_style('darkgrid')
x = np.random.randn(200)
sns.distplot(x,bins = 20,hist = True,kde = True,rug = True,norm_hist = True,axlabel);
# Out:
# D:\Setups\apps\Aanconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Setups\apps\Aanconda\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])
df
sns.jointplot(x="x", y="y", data=df,kind = 'kde');
